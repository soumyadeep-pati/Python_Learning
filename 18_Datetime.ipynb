# %% [markdown]
# # Python Datetime

# %%
# Import the datetime module and display the current date:
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2026-08-07 22:57:02.933045

# %%
# Return the year and name of weekday:
import datetime

x = datetime.datetime.now()

print(x.year)
print(x.strftime("%A"))
# Out:
# 2026
# Friday

# %% [markdown]
# # Creating Date Objects

# %%
# The datetime() class requires three parameters to create a date: year, month, day.
import datetime

x = datetime.datetime(2026, 8, 7)

print(x)
# Out:
# 2026-08-07 00:00:00

# %% [markdown]
# The datetime() class also takes parameters for time and timezone (hour, minute, second, microsecond, tzone),
#
# but they are optional, and has a default value of 0, (None for timezone).

# %% [markdown]
# # The strftime() Method

# %%
# The method is called strftime(), and takes one parameter, format, to specify the format of the returned string:
import datetime

x = datetime.datetime(2026, 8, 7)

print(x.strftime("%B"))
# Out:
# August

# %%
print(x.strftime("%Y"))
# Out:
# 2026

# %%
print(x.strftime("%B"))
# Out:
# August

# %%
print(x.strftime("%d"))
# Out:
# 07

# %%
print(x.strftime("%A"))
# Out:
# Friday
